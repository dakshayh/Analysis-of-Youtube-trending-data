# %%
import pandas as pd #load all required libraries
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime as dt

# %%
youtubeUS = pd.read_csv(r"C:\Users\vivek_000\Desktop\Python\YouTube Project\USvideos.csv") #load US data using raw string

# %%
youtubeUS.shape #check dataframe dimensions
# Out:
# (40949, 16)

# %%
youtubeGB = pd.read_csv(r"C:\Users\vivek_000\Desktop\Python\YouTube Project\GBvideos.csv") #load Great Britain youtube data

# %%
youtubeGB.shape #check dataframe dimensions
# Out:
# (38916, 16)

# %%
youtubeIN = pd.read_csv(r"C:\Users\vivek_000\Desktop\Python\YouTube Project\INvideos.csv") #load India youtube data

# %%
youtubeIN.shape #check dataframe dimensions
# Out:
# (37352, 16)

# %%
youtubeIN.head(10) #check dataframe column values to get a feel of data
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc      17.14.11
# 1  zUZ1z7FwLc8      17.14.11
# 2  10L1hZ9qa58      17.14.11
# 3  N1vE8iiEg64      17.14.11
# 4  kJzGH0PVQHQ      17.14.11
# 5  il_pSa5l98w      17.14.11
# 6  7MxiQ4v0EnE      17.14.11
# 7  c64I9HNpiOY      17.14.11
# 8  KObFEYCaRx8      17.14.11
# 9  g8QsfJhFpjY      17.14.11
#
#                                                title     channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...   Lokdhun Punjabi
# 1  पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...           HJ NEWS
# 2  Stylish Star Allu Arjun @ ChaySam Wedding Rece...              TFPC
# 3                     Eruma Saani | Tamil vs English       Eruma Saani
# 4  why Samantha became EMOTIONAL @ Samantha naga ...        Filmylooks
# 5  MCA (Middle Class Abbayi) TEASER - Nani,Sai Pa...          Dil Raju
# 6  Daang ( Full Video ) | Mankirt Aulakh | Sukh S...     Speed Records
# 7  Padmavati : Ek Dil Ek Jaan Video Song | Deepik...          T-Series
# 8  Chiranjeevi in Naga Chaitanya - Samantha Recep...  Top Telugu Media
# 9                 New bike vs Old bike - the reality         Jump Cuts
#
#    category_id              publish_time  \
# 0            1  2017-11-12T12:20:39.000Z
# 1           25  2017-11-13T05:43:56.000Z
# 2           24  2017-11-12T15:48:08.000Z
# 3           23  2017-11-12T07:08:48.000Z
# 4           24  2017-11-13T01:14:16.000Z
# 5           24  2017-11-10T04:29:50.000Z
# 6           10  2017-11-11T16:41:15.000Z
# 7           10  2017-11-11T06:14:19.000Z
# 8           24  2017-11-13T04:42:26.000Z
# 9           24  2017-11-12T04:30:01.000Z
#
#                                                 tags     views   likes  \
# 0  sharry mann|"sharry mann new song"|"sharry man...   1096327   33966
# 1  पीरियड्स के समय|"पेट पर पति करता ऐसा"|"देखकर द...    590101     735
# 2  Stylish Star Allu Arjun @ ChaySam Wedding Rece...    473988    2011
# 3  Eruma Saani|"Tamil Comedy Videos"|"Films"|"Mov...   1242680   70353
# 4  Filmylooks|"latest news"|"telugu movies"|"telu...    464015     492
# 5  Nenu Local|"Nenu Local Telugu Movie"|"Nani"|"S...   6106669   98612
# 6  punjabi songs|"punjabi bhangra"|"punjabi music...   5718766  127477
# 7  Ek Dil Ek Jaan Video Song|"'Ek Dil Ek Jaan'"|"...  10588371  132738
# 8  Chiranjeevi in Naga Chaitanya - Samantha Recep...    118223     520
# 9  Jump cuts|"Jumpcuts"|"Tamil comedy"|"Tamil Com...    969030   59798
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0       798            882  https://i.ytimg.com/vi/kzwfHumJyYc/default.jpg
# 1       904              0  https://i.ytimg.com/vi/zUZ1z7FwLc8/default.jpg
# 2       243            149  https://i.ytimg.com/vi/10L1hZ9qa58/default.jpg
# 3      1624           2684  https://i.ytimg.com/vi/N1vE8iiEg64/default.jpg
# 4       293             66  https://i.ytimg.com/vi/kJzGH0PVQHQ/default.jpg
# 5      4185           4763  https://i.ytimg.com/vi/il_pSa5l98w/default.jpg
# 6      7134           8063  https://i.ytimg.com/vi/7MxiQ4v0EnE/default.jpg
# 7      8812          10847  https://i.ytimg.com/vi/c64I9HNpiOY/default.jpg
# 8        53             23  https://i.ytimg.com/vi/KObFEYCaRx8/default.jpg
# 9      1545           2404  https://i.ytimg.com/vi/g8QsfJhFpjY/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1               True             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
# 5              False             False                   False
# 6              False             False                   False
# 7              False             False                   False
# 8              False             False                   False
# 9              False             False                   False
#
#                                          description
# 0  Presenting Sharry Mann latest Punjabi Song  Cu...
# 1  पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...
# 2  Watch Stylish Star Allu Arjun @ ChaySam Weddin...
# 3  This video showcases the difference between pe...
# 4  why Samantha became EMOTIONAL @ Samantha naga ...
# 5  Watch MCA- Middle Class Abbayi First Look Teas...
# 6  Song - Daang\nSinger - Mankirt Aulakh\nFaceboo...
# 7  Presenting the song 'Ek Dil Ek Jaan' from Padm...
# 8  Chiranjeevi in Naga Chaitanya - Samantha Recep...
# 9  Jump Cuts is a Tamil entertaining group by Har...

# %%
youtubeIN.describe() #summary statistics
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  37352.000000  3.735200e+04  3.735200e+04  3.735200e+04    37352.00000
# mean      21.576596  1.060478e+06  2.708272e+04  1.665082e+03     2676.99743
# std        6.556593  3.184932e+06  9.714510e+04  1.607617e+04    14868.31713
# min        1.000000  4.024000e+03  0.000000e+00  0.000000e+00        0.00000
# 25%       23.000000  1.239155e+05  8.640000e+02  1.080000e+02       81.00000
# 50%       24.000000  3.045860e+05  3.069000e+03  3.260000e+02      329.00000
# 75%       24.000000  7.992912e+05  1.377425e+04  1.019250e+03     1285.00000
# max       43.000000  1.254322e+08  2.912710e+06  1.545017e+06   827755.00000

# %%
us_json = pd.read_json(r"C:\Users\vivek_000\Desktop\Python\YouTube Project\US_category_id.json")

# %%
us_json.head(10) #loading json files
# Out:
#                                 kind  \
# 0  youtube#videoCategoryListResponse
# 1  youtube#videoCategoryListResponse
# 2  youtube#videoCategoryListResponse
# 3  youtube#videoCategoryListResponse
# 4  youtube#videoCategoryListResponse
# 5  youtube#videoCategoryListResponse
# 6  youtube#videoCategoryListResponse
# 7  youtube#videoCategoryListResponse
# 8  youtube#videoCategoryListResponse
# 9  youtube#videoCategoryListResponse
#
#                                                 etag  \
# 0  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 1  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 2  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 3  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 4  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 5  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 6  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 7  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 8  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 9  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
#
#                                                items
# 0  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 1  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 2  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 3  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 4  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 5  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 6  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 7  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 8  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 9  {'kind': 'youtube#videoCategory', 'etag': '"m2...

# %%
us_json.describe()
# Out:
#                                      kind  \
# count                                  32
# unique                                  1
# top     youtube#videoCategoryListResponse
# freq                                   32
#
#                                                      etag  \
# count                                                  32
# unique                                                  1
# top     "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# freq                                                   32
#
#                                                     items
# count                                                  32
# unique                                                 32
# top     {'kind': 'youtube#videoCategory', 'etag': '"m2...
# freq                                                    1

# %%
us_json.dtypes
# Out:
# kind     object
# etag     object
# items    object
# dtype: object

# %%
in_json = pd.read_json(r"C:\Users\vivek_000\Desktop\Python\YouTube Project\IN_category_id.json")

# %%
in_json.describe()
# Out:
#                                      kind  \
# count                                  31
# unique                                  1
# top     youtube#videoCategoryListResponse
# freq                                   31
#
#                                                      etag  \
# count                                                  31
# unique                                                  1
# top     "XI7nbFXulYBIpL0ayR_gDh3eu1k/1v2mrzYSYG6onNLt2...
# freq                                                   31
#
#                                                     items
# count                                                  31
# unique                                                 31
# top     {'kind': 'youtube#videoCategory', 'etag': '"XI...
# freq                                                    1

# %%
gb_json = pd.read_json(r"C:\Users\vivek_000\Desktop\Python\YouTube Project\GB_category_id.json")

# %%
gb_json.describe()
# Out:
#                                      kind  \
# count                                  31
# unique                                  1
# top     youtube#videoCategoryListResponse
# freq                                   31
#
#                                                      etag  \
# count                                                  31
# unique                                                  1
# top     "m2yskBQFythfE4irbTIeOgYYfBU/1v2mrzYSYG6onNLt2...
# freq                                                   31
#
#                                                     items
# count                                                  31
# unique                                                 31
# top     {'kind': 'youtube#videoCategory', 'etag': '"m2...
# freq                                                    1

# %%
youtubeUS.insert(0,"Country","US", True)
youtubeGB.insert(0,"Country","GB", True) #insert country column with country code
youtubeIN.insert(0,"Country","IN", True)
youtubeIN.head(10)
# Out:
#   Country     video_id trending_date  \
# 0      IN  kzwfHumJyYc      17.14.11
# 1      IN  zUZ1z7FwLc8      17.14.11
# 2      IN  10L1hZ9qa58      17.14.11
# 3      IN  N1vE8iiEg64      17.14.11
# 4      IN  kJzGH0PVQHQ      17.14.11
# 5      IN  il_pSa5l98w      17.14.11
# 6      IN  7MxiQ4v0EnE      17.14.11
# 7      IN  c64I9HNpiOY      17.14.11
# 8      IN  KObFEYCaRx8      17.14.11
# 9      IN  g8QsfJhFpjY      17.14.11
#
#                                                title     channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...   Lokdhun Punjabi
# 1  पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...           HJ NEWS
# 2  Stylish Star Allu Arjun @ ChaySam Wedding Rece...              TFPC
# 3                     Eruma Saani | Tamil vs English       Eruma Saani
# 4  why Samantha became EMOTIONAL @ Samantha naga ...        Filmylooks
# 5  MCA (Middle Class Abbayi) TEASER - Nani,Sai Pa...          Dil Raju
# 6  Daang ( Full Video ) | Mankirt Aulakh | Sukh S...     Speed Records
# 7  Padmavati : Ek Dil Ek Jaan Video Song | Deepik...          T-Series
# 8  Chiranjeevi in Naga Chaitanya - Samantha Recep...  Top Telugu Media
# 9                 New bike vs Old bike - the reality         Jump Cuts
#
#    category_id              publish_time  \
# 0            1  2017-11-12T12:20:39.000Z
# 1           25  2017-11-13T05:43:56.000Z
# 2           24  2017-11-12T15:48:08.000Z
# 3           23  2017-11-12T07:08:48.000Z
# 4           24  2017-11-13T01:14:16.000Z
# 5           24  2017-11-10T04:29:50.000Z
# 6           10  2017-11-11T16:41:15.000Z
# 7           10  2017-11-11T06:14:19.000Z
# 8           24  2017-11-13T04:42:26.000Z
# 9           24  2017-11-12T04:30:01.000Z
#
#                                                 tags     views   likes  \
# 0  sharry mann|"sharry mann new song"|"sharry man...   1096327   33966
# 1  पीरियड्स के समय|"पेट पर पति करता ऐसा"|"देखकर द...    590101     735
# 2  Stylish Star Allu Arjun @ ChaySam Wedding Rece...    473988    2011
# 3  Eruma Saani|"Tamil Comedy Videos"|"Films"|"Mov...   1242680   70353
# 4  Filmylooks|"latest news"|"telugu movies"|"telu...    464015     492
# 5  Nenu Local|"Nenu Local Telugu Movie"|"Nani"|"S...   6106669   98612
# 6  punjabi songs|"punjabi bhangra"|"punjabi music...   5718766  127477
# 7  Ek Dil Ek Jaan Video Song|"'Ek Dil Ek Jaan'"|"...  10588371  132738
# 8  Chiranjeevi in Naga Chaitanya - Samantha Recep...    118223     520
# 9  Jump cuts|"Jumpcuts"|"Tamil comedy"|"Tamil Com...    969030   59798
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0       798            882  https://i.ytimg.com/vi/kzwfHumJyYc/default.jpg
# 1       904              0  https://i.ytimg.com/vi/zUZ1z7FwLc8/default.jpg
# 2       243            149  https://i.ytimg.com/vi/10L1hZ9qa58/default.jpg
# 3      1624           2684  https://i.ytimg.com/vi/N1vE8iiEg64/default.jpg
# 4       293             66  https://i.ytimg.com/vi/kJzGH0PVQHQ/default.jpg
# 5      4185           4763  https://i.ytimg.com/vi/il_pSa5l98w/default.jpg
# 6      7134           8063  https://i.ytimg.com/vi/7MxiQ4v0EnE/default.jpg
# 7      8812          10847  https://i.ytimg.com/vi/c64I9HNpiOY/default.jpg
# 8        53             23  https://i.ytimg.com/vi/KObFEYCaRx8/default.jpg
# 9      1545           2404  https://i.ytimg.com/vi/g8QsfJhFpjY/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1               True             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
# 5              False             False                   False
# 6              False             False                   False
# 7              False             False                   False
# 8              False             False                   False
# 9              False             False                   False
#
#                                          description
# 0  Presenting Sharry Mann latest Punjabi Song  Cu...
# 1  पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...
# 2  Watch Stylish Star Allu Arjun @ ChaySam Weddin...
# 3  This video showcases the difference between pe...
# 4  why Samantha became EMOTIONAL @ Samantha naga ...
# 5  Watch MCA- Middle Class Abbayi First Look Teas...
# 6  Song - Daang\nSinger - Mankirt Aulakh\nFaceboo...
# 7  Presenting the song 'Ek Dil Ek Jaan' from Padm...
# 8  Chiranjeevi in Naga Chaitanya - Samantha Recep...
# 9  Jump Cuts is a Tamil entertaining group by Har...

# %%
youtubeUSGBIN = pd.concat([youtubeUS, youtubeGB, youtubeIN]) #concat all three dataframes

# %%
youtubeUSGBIN.describe() #summary statistisc
# Out:
#          category_id         views         likes      dislikes  comment_count
# count  117217.000000  1.172170e+05  1.172170e+05  1.172170e+05   1.172170e+05
# mean       19.439638  3.125416e+06  7.923513e+04  4.354511e+03   8.149208e+03
# std         7.581672  1.209701e+07  2.527158e+05  3.528140e+04   3.781326e+04
# min         1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%        10.000000  1.819770e+05  2.544000e+03  1.600000e+02   2.990000e+02
# 50%        24.000000  5.605360e+05  1.222400e+04  5.440000e+02   1.255000e+03
# 75%        24.000000  1.811610e+06  5.198400e+04  1.913000e+03   4.738000e+03
# max        43.000000  4.245389e+08  5.613827e+06  1.944971e+06   1.626501e+06

# %%
youtubeUSGBIN.tail(10) #peep into the data
# Out:
#       Country     video_id trending_date  \
# 37342      IN  aVHqWcTsgxc      18.14.06
# 37343      IN  zIvfX9vc0Nw      18.14.06
# 37344      IN  5gd1G0aeqtw      18.14.06
# 37345      IN  tR5FZC2FP-U      18.14.06
# 37346      IN  8aMckaI9k00      18.14.06
# 37347      IN  iNHecA3PJCo      18.14.06
# 37348      IN  dpPmPbhcslM      18.14.06
# 37349      IN  mV6aztP58f8      18.14.06
# 37350      IN  qxqDNP1bDEw      18.14.06
# 37351      IN  wERgpPK44w0      18.14.06
#
#                                                    title       channel_title  \
# 37342                 भय्यू महाराजांची सुसाईड नोट सापडली         ZEE 24 TAAS
# 37343  THINGS GUJARATIS ARE TIRED OF HEARING FT. Tath...        Hasley India
# 37344  If everything on the internet was true | Comed...    Dreamz Unlimited
# 37345                Priyamanaval Episode 1040, 13/06/18           VikatanTV
# 37346  Indore Preview- Chacha Vidhayak Hai Humare - Z...          Zakir Khan
# 37347  फेकू आशिक़ - राजस्थान की सबसे शानदार कॉमेडी | ...      RDC Rajasthani
# 37348                         Seetha | Flowers | Ep# 364          Flowers TV
# 37349  Bhramanam I Episode 87 - 12 June 2018 I Mazhav...   Mazhavil Manorama
# 37350  Nua Bohu | Full Ep 285 | 13th June 2018 | Odia...           Tarang TV
# 37351  Ee Nagaraniki Emaindi Trailer | Tharun Bhascke...  Suresh Productions
#
#        category_id              publish_time  \
# 37342           25  2018-06-12T10:27:38.000Z
# 37343           23  2018-06-11T13:17:24.000Z
# 37344           24  2018-06-13T15:33:32.000Z
# 37345           43  2018-06-13T17:00:04.000Z
# 37346           22  2018-06-13T14:18:31.000Z
# 37347           23  2018-06-13T08:01:11.000Z
# 37348           24  2018-06-13T11:30:04.000Z
# 37349           24  2018-06-13T05:00:02.000Z
# 37350           24  2018-06-13T15:07:49.000Z
# 37351           24  2018-06-10T04:29:54.000Z
#
#                                                     tags    views  likes  \
# 37342  zee24taas|"marathi video"|"marathi news"|"Brea...   339265    434
# 37343  hasley|"india"|"harsh"|"beniwal"|"rishhsome"|"...   447755  23896
# 37344  nagaland|"northeast"|"facebook"|"whatsapp"|"so...    56313   6687
# 37345  priyamanaval episode 1040|"Priyamanaval 13.06....   535254   3105
# 37346                                             [none]   274861  16448
# 37347  twinkle vaishnav comedy|"twinkle vaishnav"|"tw...   214378   3291
# 37348  flowers serials|"actress"|"malayalam serials"|...   406828   1726
# 37349  mazhavil manorama|"bhramanam full episode"|"gt...   386319   1216
# 37350  tarang|"tarang tv"|"tarang tv online"|"tarang ...   130263    698
# 37351  Ee Nagaraniki Emaindi|"Ee Nagaraniki Emaindi T...  1278249  22466
#
#        dislikes  comment_count  \
# 37342       185             73
# 37343      1304           1340
# 37344        57            556
# 37345      1403            898
# 37346       183            834
# 37347       404            196
# 37348       478           1428
# 37349       453            697
# 37350       115             65
# 37351      1609           1205
#
#                                        thumbnail_link  comments_disabled  \
# 37342  https://i.ytimg.com/vi/aVHqWcTsgxc/default.jpg              False
# 37343  https://i.ytimg.com/vi/zIvfX9vc0Nw/default.jpg              False
# 37344  https://i.ytimg.com/vi/5gd1G0aeqtw/default.jpg              False
# 37345  https://i.ytimg.com/vi/tR5FZC2FP-U/default.jpg              False
# 37346  https://i.ytimg.com/vi/8aMckaI9k00/default.jpg              False
# 37347  https://i.ytimg.com/vi/iNHecA3PJCo/default.jpg              False
# 37348  https://i.ytimg.com/vi/dpPmPbhcslM/default.jpg              False
# 37349  https://i.ytimg.com/vi/mV6aztP58f8/default.jpg              False
# 37350  https://i.ytimg.com/vi/qxqDNP1bDEw/default.jpg              False
# 37351  https://i.ytimg.com/vi/wERgpPK44w0/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 37342             False                   False
# 37343             False                   False
# 37344             False                   False
# 37345             False                   False
# 37346             False                   False
# 37347             False                   False
# 37348             False                   False
# 37349             False                   False
# 37350             False                   False
# 37351             False                   False
#
#                                              description
# 37342  Bhaiyyuji Maharaj | Suicide For Depression And...
# 37343  So we are back with a new comedy sketch on our...
# 37344  Believing everything you see and hear on the i...
# 37345  Priyamanaval Episode 1040Subscribe: https://go...
# 37346  Suno, Sab sort karva denge. Chacha vidhayak ha...
# 37347  PRG Music & RDC Rajasthani presents फेकू आशिक़...
# 37348  Flowers - A R Rahman Show,Book your Tickets He...
# 37349  Subscribe to Mazhavil Manorama now for your da...
# 37350  Nuabohu : Story of a rustic village girl who w...
# 37351  Check out Ee Nagaraniki Emaindi Trailer #EeNag...

# %%
youtubeUSGBIN.shape #shape of master dataframe
# Out:
# (117217, 17)

# %%
youtubeUSGBIN.dtypes #data types of cols
# Out:
# Country                   object
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
youtubeUSGBIN.isnull().any() #description col has some nulls
# Out:
# Country                   False
# video_id                  False
# trending_date             False
# title                     False
# channel_title             False
# category_id               False
# publish_time              False
# tags                      False
# views                     False
# likes                     False
# dislikes                  False
# comment_count             False
# thumbnail_link            False
# comments_disabled         False
# ratings_disabled          False
# video_error_or_removed    False
# description                True
# dtype: bool

# %%
youtubeUSGBIN.isna().sum() #count of nulls
# Out:
# Country                      0
# video_id                     0
# trending_date                0
# title                        0
# channel_title                0
# category_id                  0
# publish_time                 0
# tags                         0
# views                        0
# likes                        0
# dislikes                     0
# comment_count                0
# thumbnail_link               0
# comments_disabled            0
# ratings_disabled             0
# video_error_or_removed       0
# description               1743
# dtype: int64

# %%
df=youtubeUSGBIN.sample(frac=1).reset_index(drop=True) # shuffle the df for mixed country data and drop original index 
df.head(10)
# Out:
#   Country     video_id trending_date  \
# 0      IN  Q0w-uhg-5Yg      18.15.01
# 1      GB  EbSOKsFHwU8      18.31.05
# 2      IN  _PSVI84Q_WY      18.21.04
# 3      US  VNigGwmovdA      18.18.01
# 4      IN  t7I8EBOTx8Y      17.14.11
# 5      GB  gRhgPUbOIyA      18.12.01
# 6      IN  OrnpSe4OChM      18.05.05
# 7      US  khPLWaBioOs      17.14.12
# 8      GB  l884wKofd54      18.19.05
# 9      IN  GoAdwD3VBV0      18.07.05
#
#                                                title  \
# 0  NBK's Jai Simha Movie  Public Talk | Public RE...
# 1          Charlie Puth - Done For Me (Jazz Version)
# 2  Pawan Kalyan Gives 1 Day Ultimatum To Respond ...
# 3               Walmart is closing Sam's Club stores
# 4  Kannil Kannonnu song from Chemparathippoo | Vi...
# 5  PRESIDENT DONALD TRUMP CAMP DAVID SPEECH 1/6/2018
# 6                     Mean Tweets – Avengers Edition
# 7  Logan Paul - SANTA DISS TRACK (Official Music ...
# 8  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 9  Bharat Ane Nenu Farmer Uncut Scene | Mahesh Ba...
#
#                  channel_title  category_id              publish_time  \
# 0                   Dabba Guru           24  2018-01-12T08:13:04.000Z
# 1                 Charlie Puth           10  2018-05-02T16:02:50.000Z
# 2               V6 News Telugu           25  2018-04-20T16:13:58.000Z
# 3                     CNNMoney           25  2018-01-11T23:21:30.000Z
# 4         Manorama Music Songs           10  2017-11-13T11:30:01.000Z
# 5  President Trump Live Stream           25  2018-01-06T17:31:43.000Z
# 6            Jimmy Kimmel Live           23  2018-05-01T03:57:23.000Z
# 7             Logan Paul Vlogs           24  2017-12-10T21:32:44.000Z
# 8          EnriqueIglesiasVEVO           10  2018-05-09T07:00:01.000Z
# 9           DVV Entertainments           24  2018-05-05T02:39:07.000Z
#
#                                                 tags     views   likes  \
# 0  Trending|"Topics"|"2017"|"NBK's Jai Simha Movi...    625493    3240
# 1  Charlie|"Puth"|"charlie puth"|"Charlie Puth - ...   2980424  164186
# 2  Pawan Kalyan|"Pawan Kalyan Protest"|"Pawan Kal...    290738    1902
# 3  CNNMoney|"News"|"walmart"|"sam's club"|"stores...    218907    1054
# 4  Askar Ali|"Aju Vargheese"|"Sudheer Karamana"|"...     37786    1102
# 5  PRESIDENT TRUMP CAMP DAVID SPEECH|"DONALD TRUM...     31117     512
# 6  jimmy|"jimmy kimmel"|"jimmy kimmel live"|"late...  11362844  248097
# 7  logan paul vlog|"logan paul"|"logan"|"paul"|"o...  11767339  882821
# 8  Enrique Iglesias feat. Pitbull|"MOVE TO MIAMI"...  12356770  180008
# 9  Bharat Ane Nenu Farmer Uncut Scene|"Bharat Ane...   1998192   32555
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      1812            509  https://i.ytimg.com/vi/Q0w-uhg-5Yg/default.jpg
# 1      1444           7451  https://i.ytimg.com/vi/EbSOKsFHwU8/default.jpg
# 2       271            583  https://i.ytimg.com/vi/_PSVI84Q_WY/default.jpg
# 3       556           1017  https://i.ytimg.com/vi/VNigGwmovdA/default.jpg
# 4        28             54  https://i.ytimg.com/vi/t7I8EBOTx8Y/default.jpg
# 5        93            333  https://i.ytimg.com/vi/gRhgPUbOIyA/default.jpg
# 6      7884          18884  https://i.ytimg.com/vi/OrnpSe4OChM/default.jpg
# 7    117842         150856  https://i.ytimg.com/vi/khPLWaBioOs/default.jpg
# 8      8822           8216  https://i.ytimg.com/vi/l884wKofd54/default.jpg
# 9      1044           1236  https://i.ytimg.com/vi/GoAdwD3VBV0/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
# 5              False             False                   False
# 6              False             False                   False
# 7              False             False                   False
# 8              False             False                   False
# 9              False             False                   False
#
#                                          description
# 0  For More Latest Celebrity Updates and News Sub...
# 1  Download & Stream Done For Me (feat. Kehlani):...
# 2  Pawan Kalyan Gives 1 Day Ultimatum To Respond ...
# 3  Sam's Club, the buy-in-bulk store owned by Wal...
# 4  Lyrics : Jinil Jose\nMusic : Rakesh A R\nSinge...
# 5  President DONALD TRUMP News Conference at Camp...
# 6  Avengers: Infinity War just set the record for...
# 7  MAVERICK MERCH IS WHERE IT'S AT ► https://Shop...
# 8  NEW SONG - MOVE TO MIAMI feat. Pitbull (Click ...
# 9  Bharat Ane Nenu Movie, starring Superstar Mahe...

# %%
df["trending_date"] #col to clean to transform
# Out:
# 0         18.15.01
# 1         18.31.05
# 2         18.21.04
# 3         18.18.01
# 4         17.14.11
#             ...
# 117212    18.10.02
# 117213    17.23.12
# 117214    18.23.01
# 117215    18.08.01
# 117216    18.25.01
# Name: trending_date, Length: 117217, dtype: object

# %%
df["trending_date"].apply(type).value_counts() #see col type : is a string
# Out:
# <class 'str'>    117217
# Name: trending_date, dtype: int64

# %%
df["trending_date"] = pd.to_datetime(df["trending_date"], format = "%y.%d.%m") #convert to date time object with proper format
df["trending_date"]
# Out:
# 0        2018-01-15
# 1        2018-05-31
# 2        2018-04-21
# 3        2018-01-18
# 4        2017-11-14
#             ...
# 117212   2018-02-10
# 117213   2017-12-23
# 117214   2018-01-23
# 117215   2018-01-08
# 117216   2018-01-25
# Name: trending_date, Length: 117217, dtype: datetime64[ns]

# %%
df["publish_time"] #col to clean and trasnform
# Out:
# 0         2018-01-12T08:13:04.000Z
# 1         2018-05-02T16:02:50.000Z
# 2         2018-04-20T16:13:58.000Z
# 3         2018-01-11T23:21:30.000Z
# 4         2017-11-13T11:30:01.000Z
#                     ...
# 117212    2018-02-08T22:23:43.000Z
# 117213    2017-12-11T15:00:08.000Z
# 117214    2018-01-22T08:05:01.000Z
# 117215    2011-08-19T05:43:51.000Z
# 117216    2018-01-17T15:00:04.000Z
# Name: publish_time, Length: 117217, dtype: object

# %%
df["publish_time"].apply(type).value_counts() #see col type : is a string
# Out:
# <class 'str'>    117217
# Name: publish_time, dtype: int64

# %%
df["publish_time"] = df["publish_time"].str.replace("\.\d+Z\Z","") #remove micro seconds and unwanted Z at end
df["publish_time"]
# Out:
# 0         2018-01-12T08:13:04
# 1         2018-05-02T16:02:50
# 2         2018-04-20T16:13:58
# 3         2018-01-11T23:21:30
# 4         2017-11-13T11:30:01
#                  ...
# 117212    2018-02-08T22:23:43
# 117213    2017-12-11T15:00:08
# 117214    2018-01-22T08:05:01
# 117215    2011-08-19T05:43:51
# 117216    2018-01-17T15:00:04
# Name: publish_time, Length: 117217, dtype: object

# %%
df["publish_date"] = df["publish_time"].str.split("T").str[0] #split on 'T' and form two seperate columns -date & time
df["publish_time"] = df["publish_time"].str.split("T").str[1]
df
# Out:
#        Country     video_id trending_date  \
# 0           IN  Q0w-uhg-5Yg    2018-01-15
# 1           GB  EbSOKsFHwU8    2018-05-31
# 2           IN  _PSVI84Q_WY    2018-04-21
# 3           US  VNigGwmovdA    2018-01-18
# 4           IN  t7I8EBOTx8Y    2017-11-14
# ...        ...          ...           ...
# 117212      IN  47iYbraZ2bE    2018-02-10
# 117213      GB  MVyJZfFH9GI    2017-12-23
# 117214      IN  naodbT3KsO0    2018-01-23
# 117215      US  tjwWaUs_OmM    2018-01-08
# 117216      GB  qQFPikYSalg    2018-01-25
#
#                                                     title  \
# 0       NBK's Jai Simha Movie  Public Talk | Public RE...
# 1               Charlie Puth - Done For Me (Jazz Version)
# 2       Pawan Kalyan Gives 1 Day Ultimatum To Respond ...
# 3                    Walmart is closing Sam's Club stores
# 4       Kannil Kannonnu song from Chemparathippoo | Vi...
# ...                                                   ...
# 117212  Phulpakhru - फुलपाखरु - Episode 234  - Februar...
# 117213               The Adventures of Kesha & Macklemore
# 117214  రాకేష్ మాస్ట‌ర్ పై శేఖ‌ర్ మాస్ట‌ర్ సంచ‌ల‌న వ్...
# 117215  SF Museum Groundbreaking Show Survival Researc...
# 117216        Young Fathers - In My View (Official Video)
#
#                          channel_title  category_id publish_time  \
# 0                           Dabba Guru           24     08:13:04
# 1                         Charlie Puth           10     16:02:50
# 2                       V6 News Telugu           25     16:13:58
# 3                             CNNMoney           25     23:21:30
# 4                 Manorama Music Songs           10     11:30:01
# ...                                ...          ...          ...
# 117212                        Zee Yuva           24     22:23:43
# 117213                           kesha           10     15:00:08
# 117214                           OmFut           24     08:05:01
# 117215  Genuine Survival Research Labs           28     05:43:51
# 117216                   YOUNG FATHERS           10     15:00:04
#
#                                                      tags    views   likes  \
# 0       Trending|"Topics"|"2017"|"NBK's Jai Simha Movi...   625493    3240
# 1       Charlie|"Puth"|"charlie puth"|"Charlie Puth - ...  2980424  164186
# 2       Pawan Kalyan|"Pawan Kalyan Protest"|"Pawan Kal...   290738    1902
# 3       CNNMoney|"News"|"walmart"|"sam's club"|"stores...   218907    1054
# 4       Askar Ali|"Aju Vargheese"|"Sudheer Karamana"|"...    37786    1102
# ...                                                   ...      ...     ...
# 117212  Zee Yuva|"Phulpakhru"|"full episode"|"Marathi"...    99286     436
# 117213                                             [none]    24564    1609
# 117214  Sekhar Master Comments On Rakesh Master|"sekha...   100046     220
# 117215  art|"history"|"violent"|"machines"|"SRL"|"Surv...    19006      92
# 117216  Records|"Electronic"|"DJ"|"Video"|"Album"|"Sin...   131406    5103
#
#         dislikes  comment_count  \
# 0           1812            509
# 1           1444           7451
# 2            271            583
# 3            556           1017
# 4             28             54
# ...          ...            ...
# 117212        35             99
# 117213        22            139
# 117214       187             33
# 117215         6             19
# 117216       101            212
#
#                                         thumbnail_link  comments_disabled  \
# 0       https://i.ytimg.com/vi/Q0w-uhg-5Yg/default.jpg              False
# 1       https://i.ytimg.com/vi/EbSOKsFHwU8/default.jpg              False
# 2       https://i.ytimg.com/vi/_PSVI84Q_WY/default.jpg              False
# 3       https://i.ytimg.com/vi/VNigGwmovdA/default.jpg              False
# 4       https://i.ytimg.com/vi/t7I8EBOTx8Y/default.jpg              False
# ...                                                ...                ...
# 117212  https://i.ytimg.com/vi/47iYbraZ2bE/default.jpg              False
# 117213  https://i.ytimg.com/vi/MVyJZfFH9GI/default.jpg              False
# 117214  https://i.ytimg.com/vi/naodbT3KsO0/default.jpg              False
# 117215  https://i.ytimg.com/vi/tjwWaUs_OmM/default.jpg              False
# 117216  https://i.ytimg.com/vi/qQFPikYSalg/default.jpg              False
#
#         ratings_disabled  video_error_or_removed  \
# 0                  False                   False
# 1                  False                   False
# 2                  False                   False
# 3                  False                   False
# 4                  False                   False
# ...                  ...                     ...
# 117212             False                   False
# 117213             False                   False
# 117214             False                   False
# 117215             False                   False
# 117216             False                   False
#
#                                               description publish_date
# 0       For More Latest Celebrity Updates and News Sub...   2018-01-12
# 1       Download & Stream Done For Me (feat. Kehlani):...   2018-05-02
# 2       Pawan Kalyan Gives 1 Day Ultimatum To Respond ...   2018-04-20
# 3       Sam's Club, the buy-in-bulk store owned by Wal...   2018-01-11
# 4       Lyrics : Jinil Jose\nMusic : Rakesh A R\nSinge...   2017-11-13
# ...                                                   ...          ...
# 117212  http://www.ozee.com/shows/phulpakhru - Click h...   2018-02-08
# 117213  Get in line for the Adventures of Kesha & Mack...   2017-12-11
# 117214  రాకేష్ మాస్ట‌ర్ పై శేఖ‌ర్ మాస్ట‌ర్ సంచ‌ల‌న వ్...   2018-01-22
# 117215  SRL performed at the groundbreaking ceremony f...   2011-08-19
# 117216  ‘In My View’ Out Now -\nStream / Download: htt...   2018-01-17
#
# [117217 rows x 18 columns]

# %%
df["publish_date"] #col to convert to date
# Out:
# 0         2018-01-12
# 1         2018-05-02
# 2         2018-04-20
# 3         2018-01-11
# 4         2017-11-13
#              ...
# 117212    2018-02-08
# 117213    2017-12-11
# 117214    2018-01-22
# 117215    2011-08-19
# 117216    2018-01-17
# Name: publish_date, Length: 117217, dtype: object

# %%
df["publish_date"].apply(type).value_counts() #col is a string
# Out:
# <class 'str'>    117217
# Name: publish_date, dtype: int64

# %%
df["publish_date"] = pd.to_datetime(df["publish_date"], format = "%Y.%m.%d") #convert to date time object with proper format
df["publish_date"]
# Out:
# 0        2018-01-12
# 1        2018-05-02
# 2        2018-04-20
# 3        2018-01-11
# 4        2017-11-13
#             ...
# 117212   2018-02-08
# 117213   2017-12-11
# 117214   2018-01-22
# 117215   2011-08-19
# 117216   2018-01-17
# Name: publish_date, Length: 117217, dtype: datetime64[ns]

# %%
df["time_to_trend"] = df["trending_date"]-df["publish_date"] #time to trend for a video  - timedelta object
df
# Out:
#        Country     video_id trending_date  \
# 0           IN  Q0w-uhg-5Yg    2018-01-15
# 1           GB  EbSOKsFHwU8    2018-05-31
# 2           IN  _PSVI84Q_WY    2018-04-21
# 3           US  VNigGwmovdA    2018-01-18
# 4           IN  t7I8EBOTx8Y    2017-11-14
# ...        ...          ...           ...
# 117212      IN  47iYbraZ2bE    2018-02-10
# 117213      GB  MVyJZfFH9GI    2017-12-23
# 117214      IN  naodbT3KsO0    2018-01-23
# 117215      US  tjwWaUs_OmM    2018-01-08
# 117216      GB  qQFPikYSalg    2018-01-25
#
#                                                     title  \
# 0       NBK's Jai Simha Movie  Public Talk | Public RE...
# 1               Charlie Puth - Done For Me (Jazz Version)
# 2       Pawan Kalyan Gives 1 Day Ultimatum To Respond ...
# 3                    Walmart is closing Sam's Club stores
# 4       Kannil Kannonnu song from Chemparathippoo | Vi...
# ...                                                   ...
# 117212  Phulpakhru - फुलपाखरु - Episode 234  - Februar...
# 117213               The Adventures of Kesha & Macklemore
# 117214  రాకేష్ మాస్ట‌ర్ పై శేఖ‌ర్ మాస్ట‌ర్ సంచ‌ల‌న వ్...
# 117215  SF Museum Groundbreaking Show Survival Researc...
# 117216        Young Fathers - In My View (Official Video)
#
#                          channel_title  category_id publish_time  \
# 0                           Dabba Guru           24     08:13:04
# 1                         Charlie Puth           10     16:02:50
# 2                       V6 News Telugu           25     16:13:58
# 3                             CNNMoney           25     23:21:30
# 4                 Manorama Music Songs           10     11:30:01
# ...                                ...          ...          ...
# 117212                        Zee Yuva           24     22:23:43
# 117213                           kesha           10     15:00:08
# 117214                           OmFut           24     08:05:01
# 117215  Genuine Survival Research Labs           28     05:43:51
# 117216                   YOUNG FATHERS           10     15:00:04
#
#                                                      tags    views   likes  \
# 0       Trending|"Topics"|"2017"|"NBK's Jai Simha Movi...   625493    3240
# 1       Charlie|"Puth"|"charlie puth"|"Charlie Puth - ...  2980424  164186
# 2       Pawan Kalyan|"Pawan Kalyan Protest"|"Pawan Kal...   290738    1902
# 3       CNNMoney|"News"|"walmart"|"sam's club"|"stores...   218907    1054
# 4       Askar Ali|"Aju Vargheese"|"Sudheer Karamana"|"...    37786    1102
# ...                                                   ...      ...     ...
# 117212  Zee Yuva|"Phulpakhru"|"full episode"|"Marathi"...    99286     436
# 117213                                             [none]    24564    1609
# 117214  Sekhar Master Comments On Rakesh Master|"sekha...   100046     220
# 117215  art|"history"|"violent"|"machines"|"SRL"|"Surv...    19006      92
# 117216  Records|"Electronic"|"DJ"|"Video"|"Album"|"Sin...   131406    5103
#
#         dislikes  comment_count  \
# 0           1812            509
# 1           1444           7451
# 2            271            583
# 3            556           1017
# 4             28             54
# ...          ...            ...
# 117212        35             99
# 117213        22            139
# 117214       187             33
# 117215         6             19
# 117216       101            212
#
#                                         thumbnail_link  comments_disabled  \
# 0       https://i.ytimg.com/vi/Q0w-uhg-5Yg/default.jpg              False
# 1       https://i.ytimg.com/vi/EbSOKsFHwU8/default.jpg              False
# 2       https://i.ytimg.com/vi/_PSVI84Q_WY/default.jpg              False
# 3       https://i.ytimg.com/vi/VNigGwmovdA/default.jpg              False
# 4       https://i.ytimg.com/vi/t7I8EBOTx8Y/default.jpg              False
# ...                                                ...                ...
# 117212  https://i.ytimg.com/vi/47iYbraZ2bE/default.jpg              False
# 117213  https://i.ytimg.com/vi/MVyJZfFH9GI/default.jpg              False
# 117214  https://i.ytimg.com/vi/naodbT3KsO0/default.jpg              False
# 117215  https://i.ytimg.com/vi/tjwWaUs_OmM/default.jpg              False
# 117216  https://i.ytimg.com/vi/qQFPikYSalg/default.jpg              False
#
#         ratings_disabled  video_error_or_removed  \
# 0                  False                   False
# 1                  False                   False
# 2                  False                   False
# 3                  False                   False
# 4                  False                   False
# ...                  ...                     ...
# 117212             False                   False
# 117213             False                   False
# 117214             False                   False
# 117215             False                   False
# 117216             False                   False
#
#                                               description publish_date  \
# 0       For More Latest Celebrity Updates and News Sub...   2018-01-12
# 1       Download & Stream Done For Me (feat. Kehlani):...   2018-05-02
# 2       Pawan Kalyan Gives 1 Day Ultimatum To Respond ...   2018-04-20
# 3       Sam's Club, the buy-in-bulk store owned by Wal...   2018-01-11
# 4       Lyrics : Jinil Jose\nMusic : Rakesh A R\nSinge...   2017-11-13
# ...                                                   ...          ...
# 117212  http://www.ozee.com/shows/phulpakhru - Click h...   2018-02-08
# 117213  Get in line for the Adventures of Kesha & Mack...   2017-12-11
# 117214  రాకేష్ మాస్ట‌ర్ పై శేఖ‌ర్ మాస్ట‌ర్ సంచ‌ల‌న వ్...   2018-01-22
# 117215  SRL performed at the groundbreaking ceremony f...   2011-08-19
# 117216  ‘In My View’ Out Now -\nStream / Download: htt...   2018-01-17
#
#        time_to_trend
# 0             3 days
# 1            29 days
# 2             1 days
# 3             7 days
# 4             1 days
# ...              ...
# 117212        2 days
# 117213       12 days
# 117214        1 days
# 117215     2334 days
# 117216        8 days
#
# [117217 rows x 19 columns]

# %%
df["time_to_trend"].apply(type).value_counts() #time delta object
# Out:
# <class 'pandas._libs.tslibs.timedeltas.Timedelta'>    117217
# Name: time_to_trend, dtype: int64

# %%
df["time_to_trend"]/3  #arithmetic operations possible on this !!
# Out:
# 0          1 days 00:00:00
# 1          9 days 16:00:00
# 2          0 days 08:00:00
# 3          2 days 08:00:00
# 4          0 days 08:00:00
#                 ...
# 117212     0 days 16:00:00
# 117213     4 days 00:00:00
# 117214     0 days 08:00:00
# 117215   778 days 00:00:00
# 117216     2 days 16:00:00
# Name: time_to_trend, Length: 117217, dtype: timedelta64[ns]

# %%
df["time_to_trend"].max() #max trend time
# Out:
# Timedelta('4215 days 00:00:00')

# %%
df.dtypes #check all col data type again
# Out:
# Country                            object
# video_id                           object
# trending_date              datetime64[ns]
# title                              object
# channel_title                      object
# category_id                         int64
# publish_time                       object
# tags                               object
# views                               int64
# likes                               int64
# dislikes                            int64
# comment_count                       int64
# thumbnail_link                     object
# comments_disabled                    bool
# ratings_disabled                     bool
# video_error_or_removed               bool
# description                        object
# publish_date               datetime64[ns]
# time_to_trend             timedelta64[ns]
# dtype: object

# %%
df["tags"] #col to extract information
# Out:
# 0         Trending|"Topics"|"2017"|"NBK's Jai Simha Movi...
# 1         Charlie|"Puth"|"charlie puth"|"Charlie Puth - ...
# 2         Pawan Kalyan|"Pawan Kalyan Protest"|"Pawan Kal...
# 3         CNNMoney|"News"|"walmart"|"sam's club"|"stores...
# 4         Askar Ali|"Aju Vargheese"|"Sudheer Karamana"|"...
#                                 ...
# 117212    Zee Yuva|"Phulpakhru"|"full episode"|"Marathi"...
# 117213                                               [none]
# 117214    Sekhar Master Comments On Rakesh Master|"sekha...
# 117215    art|"history"|"violent"|"machines"|"SRL"|"Surv...
# 117216    Records|"Electronic"|"DJ"|"Video"|"Album"|"Sin...
# Name: tags, Length: 117217, dtype: object

# %%
df["tags"].apply(type).value_counts() #object with all rows in col as string
# Out:
# <class 'str'>    117217
# Name: tags, dtype: int64

# %%
countlist=[]
for i in df["tags"]: #count the no. of tags ( pipes '|' plus one if any tags exist) to see if tag affects popularity
    if("|" in i):
        count=1
        for j in i:
            if(j == "|"):
                count+=1
        countlist.append(count)
    else:
        countlist.append(0)

countlist[40:50] #see 10 random tag counts
# Out:
# [23, 25, 22, 34, 12, 29, 15, 13, 20, 7]

# %%
df["Tag_count"]= countlist #add a col for tag count
df
# Out:
#        Country     video_id trending_date  \
# 0           IN  Q0w-uhg-5Yg    2018-01-15
# 1           GB  EbSOKsFHwU8    2018-05-31
# 2           IN  _PSVI84Q_WY    2018-04-21
# 3           US  VNigGwmovdA    2018-01-18
# 4           IN  t7I8EBOTx8Y    2017-11-14
# ...        ...          ...           ...
# 117212      IN  47iYbraZ2bE    2018-02-10
# 117213      GB  MVyJZfFH9GI    2017-12-23
# 117214      IN  naodbT3KsO0    2018-01-23
# 117215      US  tjwWaUs_OmM    2018-01-08
# 117216      GB  qQFPikYSalg    2018-01-25
#
#                                                     title  \
# 0       NBK's Jai Simha Movie  Public Talk | Public RE...
# 1               Charlie Puth - Done For Me (Jazz Version)
# 2       Pawan Kalyan Gives 1 Day Ultimatum To Respond ...
# 3                    Walmart is closing Sam's Club stores
# 4       Kannil Kannonnu song from Chemparathippoo | Vi...
# ...                                                   ...
# 117212  Phulpakhru - फुलपाखरु - Episode 234  - Februar...
# 117213               The Adventures of Kesha & Macklemore
# 117214  రాకేష్ మాస్ట‌ర్ పై శేఖ‌ర్ మాస్ట‌ర్ సంచ‌ల‌న వ్...
# 117215  SF Museum Groundbreaking Show Survival Researc...
# 117216        Young Fathers - In My View (Official Video)
#
#                          channel_title  category_id publish_time  \
# 0                           Dabba Guru           24     08:13:04
# 1                         Charlie Puth           10     16:02:50
# 2                       V6 News Telugu           25     16:13:58
# 3                             CNNMoney           25     23:21:30
# 4                 Manorama Music Songs           10     11:30:01
# ...                                ...          ...          ...
# 117212                        Zee Yuva           24     22:23:43
# 117213                           kesha           10     15:00:08
# 117214                           OmFut           24     08:05:01
# 117215  Genuine Survival Research Labs           28     05:43:51
# 117216                   YOUNG FATHERS           10     15:00:04
#
#                                                      tags    views   likes  \
# 0       Trending|"Topics"|"2017"|"NBK's Jai Simha Movi...   625493    3240
# 1       Charlie|"Puth"|"charlie puth"|"Charlie Puth - ...  2980424  164186
# 2       Pawan Kalyan|"Pawan Kalyan Protest"|"Pawan Kal...   290738    1902
# 3       CNNMoney|"News"|"walmart"|"sam's club"|"stores...   218907    1054
# 4       Askar Ali|"Aju Vargheese"|"Sudheer Karamana"|"...    37786    1102
# ...                                                   ...      ...     ...
# 117212  Zee Yuva|"Phulpakhru"|"full episode"|"Marathi"...    99286     436
# 117213                                             [none]    24564    1609
# 117214  Sekhar Master Comments On Rakesh Master|"sekha...   100046     220
# 117215  art|"history"|"violent"|"machines"|"SRL"|"Surv...    19006      92
# 117216  Records|"Electronic"|"DJ"|"Video"|"Album"|"Sin...   131406    5103
#
#         dislikes  comment_count  \
# 0           1812            509
# 1           1444           7451
# 2            271            583
# 3            556           1017
# 4             28             54
# ...          ...            ...
# 117212        35             99
# 117213        22            139
# 117214       187             33
# 117215         6             19
# 117216       101            212
#
#                                         thumbnail_link  comments_disabled  \
# 0       https://i.ytimg.com/vi/Q0w-uhg-5Yg/default.jpg              False
# 1       https://i.ytimg.com/vi/EbSOKsFHwU8/default.jpg              False
# 2       https://i.ytimg.com/vi/_PSVI84Q_WY/default.jpg              False
# 3       https://i.ytimg.com/vi/VNigGwmovdA/default.jpg              False
# 4       https://i.ytimg.com/vi/t7I8EBOTx8Y/default.jpg              False
# ...                                                ...                ...
# 117212  https://i.ytimg.com/vi/47iYbraZ2bE/default.jpg              False
# 117213  https://i.ytimg.com/vi/MVyJZfFH9GI/default.jpg              False
# 117214  https://i.ytimg.com/vi/naodbT3KsO0/default.jpg              False
# 117215  https://i.ytimg.com/vi/tjwWaUs_OmM/default.jpg              False
# 117216  https://i.ytimg.com/vi/qQFPikYSalg/default.jpg              False
#
#         ratings_disabled  video_error_or_removed  \
# 0                  False                   False
# 1                  False                   False
# 2                  False                   False
# 3                  False                   False
# 4                  False                   False
# ...                  ...                     ...
# 117212             False                   False
# 117213             False                   False
# 117214             False                   False
# 117215             False                   False
# 117216             False                   False
#
#                                               description publish_date  \
# 0       For More Latest Celebrity Updates and News Sub...   2018-01-12
# 1       Download & Stream Done For Me (feat. Kehlani):...   2018-05-02
# 2       Pawan Kalyan Gives 1 Day Ultimatum To Respond ...   2018-04-20
# 3       Sam's Club, the buy-in-bulk store owned by Wal...   2018-01-11
# 4       Lyrics : Jinil Jose\nMusic : Rakesh A R\nSinge...   2017-11-13
# ...                                                   ...          ...
# 117212  http://www.ozee.com/shows/phulpakhru - Click h...   2018-02-08
# 117213  Get in line for the Adventures of Kesha & Mack...   2017-12-11
# 117214  రాకేష్ మాస్ట‌ర్ పై శేఖ‌ర్ మాస్ట‌ర్ సంచ‌ల‌న వ్...   2018-01-22
# 117215  SRL performed at the groundbreaking ceremony f...   2011-08-19
# 117216  ‘In My View’ Out Now -\nStream / Download: htt...   2018-01-17
#
#        time_to_trend  Tag_count
# 0             3 days         23
# 1            29 days         21
# 2             1 days         22
# 3             7 days         11
# 4             1 days         10
# ...              ...        ...
# 117212        2 days         10
# 117213       12 days          0
# 117214        1 days         20
# 117215     2334 days         16
# 117216        8 days         22
#
# [117217 rows x 20 columns]

# %%
df["Tag_count"].apply(type).value_counts() #col is an integer
# Out:
# <class 'int'>    117217
# Name: Tag_count, dtype: int64

# %%
df.corr() #correlation matrix
# Out:
#                         category_id     views     likes  dislikes  \
# category_id                1.000000 -0.183595 -0.198128 -0.043120
# views                     -0.183595  1.000000  0.794798  0.410891
# likes                     -0.198128  0.794798  1.000000  0.452533
# dislikes                  -0.043120  0.410891  0.452533  1.000000
# comment_count             -0.084678  0.496715  0.766640  0.742981
# comments_disabled          0.046372 -0.011090 -0.038504 -0.009419
# ratings_disabled           0.015441 -0.003056 -0.032181 -0.012668
# video_error_or_removed    -0.025835  0.010737  0.010439  0.009101
# Tag_count                  0.102668 -0.027223 -0.048057  0.013538
#
#                         comment_count  comments_disabled  ratings_disabled  \
# category_id                 -0.084678           0.046372          0.015441
# views                        0.496715          -0.011090         -0.003056
# likes                        0.766640          -0.038504         -0.032181
# dislikes                     0.742981          -0.009419         -0.012668
# comment_count                1.000000          -0.031945         -0.021371
# comments_disabled           -0.031945           1.000000          0.384370
# ratings_disabled            -0.021371           0.384370          1.000000
# video_error_or_removed       0.004624          -0.004396         -0.003044
# Tag_count                   -0.011302          -0.034442         -0.051538
#
#                         video_error_or_removed  Tag_count
# category_id                          -0.025835   0.102668
# views                                 0.010737  -0.027223
# likes                                 0.010439  -0.048057
# dislikes                              0.009101   0.013538
# comment_count                         0.004624  -0.011302
# comments_disabled                    -0.004396  -0.034442
# ratings_disabled                     -0.003044  -0.051538
# video_error_or_removed                1.000000   0.005488
# Tag_count                             0.005488   1.000000

# %%
df.plot(kind='scatter',x='Tag_count',y='likes',color='red') #between tag count and time to trend
plt.show()
